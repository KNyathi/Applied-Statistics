# %% [markdown]
# ### Question 1

# %%
import math

# %%
# Given sequences
a1 = [9.577, 12.628, 11.003, 12.512]
a2 = [12.718, 6.167, 9.919, 12.095, 5.811, 5.706]
a3 = [12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]
a4 = [11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]

# %% [markdown]
# ### Question 2

# %%
# Function to calculate mean of a sample
def mean_sample(data):
    return sum(data) / len(data)


# Function to calculate mean of squares of sample
def mean_of_squares_sample(data):
    return sum(x**2 for x in data) / len(data)


# Function to calculate unbiased sample variance
def unbiased_sample_variance(data, mean_sample, mean_of_squares_sample):
    N = len(data)
    if N < 2:
        return None
    return (N / (N - 1)) * (mean_of_squares_sample - mean_sample**2)

#Function to calculate standard deviation
def standard_deviation(variance_value):
    if variance_value is None or variance_value == 0:
        return None
    return math.sqrt(variance_value)

# %%
import numpy as np

# Function to calculate mean, variance, and standard deviation
def calculate_statistics(sequence):
    mean = mean_sample(sequence)
    mean_square = mean_of_squares_sample(sequence)
    variance = unbiased_sample_variance(sequence, mean, mean_square) 
    std_dev = standard_deviation(variance)
    return mean, variance, std_dev

# %%
import matplotlib.pyplot as plt
def draw_graph_mat_exp(n_values, mat_values, lower_bounds, upper_bounds, individual_means):
    # Plotting the results
    plt.figure(figsize=(10, 6))
    plt.plot(n_values, mat_values, marker='o', linestyle='dashdot', label="M_s (Average mathematical exp)", color="blue")
    plt.plot(n_values, lower_bounds, marker='o', linestyle='--',  label="M_min_i (Lower Bound)", color="red")
    plt.plot(n_values, upper_bounds, marker='o', linestyle='--', label="M_max_i (Upper Bound)", color="green")
    plt.plot(n_values, individual_means, marker='o', label="Mi (Individual Means)", color="purple")

    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('Ni (Sample Size)')
    plt.ylabel('Mean Value')
    plt.title('Confidence Intervals for Mean')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.show()


def draw_graph_std(n_values, individual_std, std_values, std_min_intervals, std_max_intervals ):
    # Plotting the results
    plt.figure(figsize=(10, 6))
    plt.plot(n_values, individual_std, marker='o', label='S_i (Calculated Standard Deviation)')
    plt.plot(n_values, std_values, marker='o', linestyle='dashdot', label="Sc (Average std)", color="blue")
    plt.plot(n_values, std_min_intervals, marker='x', linestyle='--', label='S_min_i (Lower Bound)')
    plt.plot(n_values, std_max_intervals, marker='x', linestyle='--', label='S_max_i (Upper Bound)')
    plt.xscale('log')
    plt.yscale('log')

    plt.xlabel('Ni (Sample Size)')
    plt.ylabel('Standard Deviation')
    plt.title('Confidence Intervals for Standard Deviation')
    plt.legend()
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)

    plt.show()

# %% [markdown]
# ### Question 3, 4, 5, 6, 7

# %%
from scipy.stats import norm, t
import scipy.stats as stats

# Define the significance level
p_values = [0.1, 0.05, 0.02, 0.01]


for p in p_values:
    print(f"_______WHERE p={p}_________\n")
    # Calculate and print statistics for each sequence
    exp_values = []

    # Calculate statistics and confidence intervals for each sequence
    lower_bounds = []
    upper_bounds = []
    individual_means = []

    std_min_intervals = []
    std_max_intervals = []
    individual_std = []

    for i, seq in enumerate([a1, a2, a3, a4], start=1):
        mean, variance, std_dev = calculate_statistics(seq)
        n = len(seq)

        # Store individual means and stds
        individual_means.append(mean)
        individual_std.append(std_dev)

        #mean_of_means = sum(exp_values)/len(exp_values)
        
        print(f"Statistics for a{i} where n={n}:")
        print(f"  Mean = {mean:.3f}")
        print(f"  Variance = {variance:.3f}")
        print(f"  Standard Deviation = {std_dev:.3f}")
        print()


        # Normal distribution critical value
        normal_quantile = norm.ppf(1 - p / 2)
        a_min = mean - normal_quantile * (std_dev / math.sqrt(n))
        a_max = mean + normal_quantile * (std_dev / math.sqrt(n))
        print(f"Normal Distribution Critical Value a{i} (seq={seq}) (p={p}): {normal_quantile:.3f} \n")
        print(f"a_min = {a_min}")
        print(f"a_max = {a_max} \n")

        # Store upper and lower quantiles
        lower_bounds.append(a_min)
        upper_bounds.append(a_max)

        # Student's t-distribution critical value
        t_quantile = t.ppf(1 - p / 2, df=n - 1)
        a_min_t = mean - t_quantile * (std_dev / math.sqrt(n))
        a_max_t = mean + t_quantile * (std_dev / math.sqrt(n))
        print(f"Student's t-Distribution Critical Value for a{i} (seq={seq}): {t_quantile:.3f}\n")
        print(f"a_min_t = {a_min_t}")
        print(f"a_max_t = {a_max_t}\n")

        # Calculate the chi-squared critical values for the given p
        chi2_upper = stats.chi2.ppf(1 - p / 2, df=n - 1)
        chi2_lower = stats.chi2.ppf(p / 2, df=n - 1)

        print(f"Sequence a{i} with n = {n}")
        print(f"  Chi-squared upper critical value (1 - p/2): {chi2_upper:.3f}")
        print(f"  Chi-squared lower critical value (p/2): {chi2_lower:.3f}\n")

        
        # Calculate the confidence interval for variance
        s_min_2 = ((std_dev**2) * (n - 1)) / chi2_upper
        s_max_2 = ((std_dev**2) * (n - 1)) / chi2_lower
        
        # Calculate the confidence interval for standard deviation
        s_a_min = math.sqrt(s_min_2)
        s_a_max = math.sqrt(s_max_2)
        
        std_min_intervals.append(s_a_min)
        std_max_intervals.append(s_a_max)


        print(f"Confidence interval for variance and standard deviation for sequence a{i}:")
        print(f" s_min_2: {s_min_2:.3f}, s_max_2: {s_max_2:.3f}")
        print(f" s_a_min: {s_a_min:.3f}, s_a_max: {s_a_max:.3f}\n")


        
        print(f"______________________________________________________________________________________________________________________________________________\n")
        
    mean_values = sum(individual_means) / len(individual_means)
    mat_values = [mean_values] * 4

    # Calculate M_s (mean of all means)
    std_avg = math.sqrt((3*(individual_std[0]**2) + 5*(individual_std[1]**2) + 9*(individual_std[2]**2) + 11*(individual_std[3]**2))/(4+6+10+12-4))
    std_values = [std_avg] * 4

    print(f"  Average mathematical exp = {mean_values:.3f}")
    print(f"  Average standard deviation = {std_avg:.3f}")
    #print(*std_values)

    #print(*lower_bounds)
    #print(*upper_bounds)
    #print(*individual_means) 

    #print(*std_min_intervals)
    #print(*std_max_intervals)
    #print(*individual_std)

    n_values = [4, 6, 10, 12]

    draw_graph_mat_exp(n_values, mat_values, lower_bounds, upper_bounds, individual_means)
    draw_graph_std(n_values, individual_std, std_values, std_min_intervals, std_max_intervals )
# Out:
# _______WHERE p=0.1_________
#
# Statistics for a1 where n=4:
#   Mean = 11.430
#   Variance = 2.074
#   Standard Deviation = 1.440
#
# Normal Distribution Critical Value a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.1): 1.645
#
# a_min = 10.245603922225946
# a_max = 12.614396077774053
#
# Student's t-Distribution Critical Value for a1 (seq=[9.577, 12.628, 11.003, 12.512]): 2.353
#
# a_min_t = 9.73543315460714
# a_max_t = 13.12456684539286
#
# Sequence a1 with n = 4
#   Chi-squared upper critical value (1 - p/2): 7.815
#   Chi-squared lower critical value (p/2): 0.352
#
# Confidence interval for variance and standard deviation for sequence a1:
#  s_min_2: 0.796, s_max_2: 17.683
#  s_a_min: 0.892, s_a_max: 4.205
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a2 where n=6:
#   Mean = 8.736
#   Variance = 10.575
#   Standard Deviation = 3.252
#
# Normal Distribution Critical Value a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.1): 1.645
#
# a_min = 6.552306217862146
# a_max = 10.919693782137855
#
# Student's t-Distribution Critical Value for a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 2.015
#
# a_min_t = 6.060838800240273
# a_max_t = 11.411161199759729
#
# Sequence a2 with n = 6
#   Chi-squared upper critical value (1 - p/2): 11.070
#   Chi-squared lower critical value (p/2): 1.145
#
# Confidence interval for variance and standard deviation for sequence a2:
#  s_min_2: 4.776, s_max_2: 46.160
#  s_a_min: 2.185, s_a_max: 6.794
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a3 where n=10:
#   Mean = 10.442
#   Variance = 15.591
#   Standard Deviation = 3.949
#
# Normal Distribution Critical Value a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.1): 1.645
#
# a_min = 8.388528324926808
# a_max = 12.496221649677556
#
# Student's t-Distribution Critical Value for a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 1.833
#
# a_min_t = 8.153458322136283
# a_max_t = 12.731291652468082
#
# Sequence a3 with n = 10
#   Chi-squared upper critical value (1 - p/2): 16.919
#   Chi-squared lower critical value (p/2): 3.325
#
# Confidence interval for variance and standard deviation for sequence a3:
#  s_min_2: 8.294, s_max_2: 42.201
#  s_a_min: 2.880, s_a_max: 6.496
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a4 where n=12:
#   Mean = 11.821
#   Variance = 12.643
#   Standard Deviation = 3.556
#
# Normal Distribution Critical Value a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.1): 1.645
#
# a_min = 10.132284037755607
# a_max = 13.508925636567454
#
# Student's t-Distribution Critical Value for a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 1.796
#
# a_min_t = 9.977261670891945
# a_max_t = 13.663948003431116
#
# Sequence a4 with n = 12
#   Chi-squared upper critical value (1 - p/2): 19.675
#   Chi-squared lower critical value (p/2): 4.575
#
# Confidence interval for variance and standard deviation for sequence a4:
#  s_min_2: 7.068, s_max_2: 30.399
#  s_a_min: 2.659, s_a_max: 5.514
#
# ______________________________________________________________________________________________________________________________________________
#
#   Average mathematical exp = 10.607
#   Average standard deviation = 3.477
# _______WHERE p=0.05_________
#
# Statistics for a1 where n=4:
#   Mean = 11.430
#   Variance = 2.074
#   Standard Deviation = 1.440
#
# Normal Distribution Critical Value a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.05): 1.960
#
# a_min = 10.018705026495264
# a_max = 12.841294973504736
#
# Student's t-Distribution Critical Value for a1 (seq=[9.577, 12.628, 11.003, 12.512]): 3.182
#
# a_min_t = 9.138442344081955
# a_max_t = 13.721557655918044
#
# Sequence a1 with n = 4
#   Chi-squared upper critical value (1 - p/2): 9.348
#   Chi-squared lower critical value (p/2): 0.216
#
# Confidence interval for variance and standard deviation for sequence a1:
#  s_min_2: 0.666, s_max_2: 28.832
#  s_a_min: 0.816, s_a_max: 5.370
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a2 where n=6:
#   Mean = 8.736
#   Variance = 10.575
#   Standard Deviation = 3.252
#
# Normal Distribution Critical Value a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.05): 1.960
#
# a_min = 6.133968368658667
# a_max = 11.338031631341334
#
# Student's t-Distribution Critical Value for a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 2.571
#
# a_min_t = 5.3233172657339916
# a_max_t = 12.14868273426601
#
# Sequence a2 with n = 6
#   Chi-squared upper critical value (1 - p/2): 12.833
#   Chi-squared lower critical value (p/2): 0.831
#
# Confidence interval for variance and standard deviation for sequence a2:
#  s_min_2: 4.120, s_max_2: 63.612
#  s_a_min: 2.030, s_a_max: 7.976
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a3 where n=10:
#   Mean = 10.442
#   Variance = 15.591
#   Standard Deviation = 3.949
#
# Normal Distribution Critical Value a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.05): 1.960
#
# a_min = 7.995065742233233
# a_max = 12.889684232371131
#
# Student's t-Distribution Critical Value for a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 2.262
#
# a_min_t = 7.617732197004097
# a_max_t = 13.267017777600268
#
# Sequence a3 with n = 10
#   Chi-squared upper critical value (1 - p/2): 19.023
#   Chi-squared lower critical value (p/2): 2.700
#
# Confidence interval for variance and standard deviation for sequence a3:
#  s_min_2: 7.376, s_max_2: 51.963
#  s_a_min: 2.716, s_a_max: 7.209
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a4 where n=12:
#   Mean = 11.821
#   Variance = 12.643
#   Standard Deviation = 3.556
#
# Normal Distribution Critical Value a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.05): 1.960
#
# a_min = 9.808846522035106
# a_max = 13.832363152287956
#
# Student's t-Distribution Critical Value for a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 2.201
#
# a_min_t = 9.561456081269558
# a_max_t = 14.079753593053503
#
# Sequence a4 with n = 12
#   Chi-squared upper critical value (1 - p/2): 21.920
#   Chi-squared lower critical value (p/2): 3.816
#
# Confidence interval for variance and standard deviation for sequence a4:
#  s_min_2: 6.344, s_max_2: 36.446
#  s_a_min: 2.519, s_a_max: 6.037
#
# ______________________________________________________________________________________________________________________________________________
#
#   Average mathematical exp = 10.607
#   Average standard deviation = 3.477
# _______WHERE p=0.02_________
#
# Statistics for a1 where n=4:
#   Mean = 11.430
#   Variance = 2.074
#   Standard Deviation = 1.440
#
# Normal Distribution Critical Value a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.02): 2.326
#
# a_min = 9.7548860248686
# a_max = 13.105113975131399
#
# Student's t-Distribution Critical Value for a1 (seq=[9.577, 12.628, 11.003, 12.512]): 4.541
#
# a_min_t = 8.160413838617806
# a_max_t = 14.699586161382193
#
# Sequence a1 with n = 4
#   Chi-squared upper critical value (1 - p/2): 11.345
#   Chi-squared lower critical value (p/2): 0.115
#
# Confidence interval for variance and standard deviation for sequence a1:
#  s_min_2: 0.548, s_max_2: 54.182
#  s_a_min: 0.741, s_a_max: 7.361
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a2 where n=6:
#   Mean = 8.736
#   Variance = 10.575
#   Standard Deviation = 3.252
#
# Normal Distribution Critical Value a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.02): 2.326
#
# a_min = 5.647560211562537
# a_max = 11.824439788437465
#
# Student's t-Distribution Critical Value for a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 3.365
#
# a_min_t = 4.268747354813878
# a_max_t = 13.203252645186122
#
# Sequence a2 with n = 6
#   Chi-squared upper critical value (1 - p/2): 15.086
#   Chi-squared lower critical value (p/2): 0.554
#
# Confidence interval for variance and standard deviation for sequence a2:
#  s_min_2: 3.505, s_max_2: 95.391
#  s_a_min: 1.872, s_a_max: 9.767
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a3 where n=10:
#   Mean = 10.442
#   Variance = 15.591
#   Standard Deviation = 3.949
#
# Normal Distribution Critical Value a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.02): 2.326
#
# a_min = 7.537580458272766
# a_max = 13.347169516331599
#
# Student's t-Distribution Critical Value for a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 2.821
#
# a_min_t = 6.919386213760022
# a_max_t = 13.965363760844342
#
# Sequence a3 with n = 10
#   Chi-squared upper critical value (1 - p/2): 21.666
#   Chi-squared lower critical value (p/2): 2.088
#
# Confidence interval for variance and standard deviation for sequence a3:
#  s_min_2: 6.477, s_max_2: 67.207
#  s_a_min: 2.545, s_a_max: 8.198
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a4 where n=12:
#   Mean = 11.821
#   Variance = 12.643
#   Standard Deviation = 3.556
#
# Normal Distribution Critical Value a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.02): 2.326
#
# a_min = 9.432780511615768
# a_max = 14.208429162707294
#
# Student's t-Distribution Critical Value for a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 2.718
#
# a_min_t = 9.030697246113164
# a_max_t = 14.610512428209898
#
# Sequence a4 with n = 12
#   Chi-squared upper critical value (1 - p/2): 24.725
#   Chi-squared lower critical value (p/2): 3.053
#
# Confidence interval for variance and standard deviation for sequence a4:
#  s_min_2: 5.625, s_max_2: 45.544
#  s_a_min: 2.372, s_a_max: 6.749
#
# ______________________________________________________________________________________________________________________________________________
#
#   Average mathematical exp = 10.607
#   Average standard deviation = 3.477
# _______WHERE p=0.01_________
#
# Statistics for a1 where n=4:
#   Mean = 11.430
#   Variance = 2.074
#   Standard Deviation = 1.440
#
# Normal Distribution Critical Value a1 (seq=[9.577, 12.628, 11.003, 12.512]) (p=0.01): 2.576
#
# a_min = 9.575244005818885
# a_max = 13.284755994181115
#
# Student's t-Distribution Critical Value for a1 (seq=[9.577, 12.628, 11.003, 12.512]): 5.841
#
# a_min_t = 7.224184994997363
# a_max_t = 15.635815005002637
#
# Sequence a1 with n = 4
#   Chi-squared upper critical value (1 - p/2): 12.838
#   Chi-squared lower critical value (p/2): 0.072
#
# Confidence interval for variance and standard deviation for sequence a1:
#  s_min_2: 0.485, s_max_2: 86.750
#  s_a_min: 0.696, s_a_max: 9.314
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a2 where n=6:
#   Mean = 8.736
#   Variance = 10.575
#   Standard Deviation = 3.252
#
# Normal Distribution Critical Value a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]) (p=0.01): 2.576
#
# a_min = 5.316350772954121
# a_max = 12.155649227045881
#
# Student's t-Distribution Critical Value for a2 (seq=[12.718, 6.167, 9.919, 12.095, 5.811, 5.706]): 4.032
#
# a_min_t = 3.3829610319039425
# a_max_t = 14.089038968096059
#
# Sequence a2 with n = 6
#   Chi-squared upper critical value (1 - p/2): 16.750
#   Chi-squared lower critical value (p/2): 0.412
#
# Confidence interval for variance and standard deviation for sequence a2:
#  s_min_2: 3.157, s_max_2: 128.418
#  s_a_min: 1.777, s_a_max: 11.332
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a3 where n=10:
#   Mean = 10.442
#   Variance = 15.591
#   Standard Deviation = 3.949
#
# Normal Distribution Critical Value a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]) (p=0.01): 2.576
#
# a_min = 7.226065443852043
# a_max = 13.658684530752321
#
# Student's t-Distribution Critical Value for a3 (seq=[12.016323622186091, 9.259246505609095, 17.345717938437094, 5.900356369978998, 13.68768256707768, 6.507839378250566, 13.61900518222573, 5.948196429498942, 12.475855480039662, 7.66352639971797]): 3.250
#
# a_min_t = 6.384467477492041
# a_max_t = 14.500282497112323
#
# Sequence a3 with n = 10
#   Chi-squared upper critical value (1 - p/2): 23.589
#   Chi-squared lower critical value (p/2): 1.735
#
# Confidence interval for variance and standard deviation for sequence a3:
#  s_min_2: 5.949, s_max_2: 80.880
#  s_a_min: 2.439, s_a_max: 8.993
#
# ______________________________________________________________________________________________________________________________________________
#
# Statistics for a4 where n=12:
#   Mean = 11.821
#   Variance = 12.643
#   Standard Deviation = 3.556
#
# Normal Distribution Critical Value a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]) (p=0.01): 2.576
#
# a_min = 9.176706244822418
# a_max = 14.464503429500644
#
# Student's t-Distribution Critical Value for a4 (seq=[11.896107580638313, 12.354328210962015, 5.35925979227144, 13.891229335546084, 10.170697806598511, 9.255832053277832, 16.561279953259266, 10.498005569850374, 9.716219531175344, 14.094420948209105, 9.558324283707853, 18.491552980442233]): 3.106
#
# a_min_t = 8.632723770248655
# a_max_t = 15.008485904074407
#
# Sequence a4 with n = 12
#   Chi-squared upper critical value (1 - p/2): 26.757
#   Chi-squared lower critical value (p/2): 2.603
#
# Confidence interval for variance and standard deviation for sequence a4:
#  s_min_2: 5.197, s_max_2: 53.422
#  s_a_min: 2.280, s_a_max: 7.309
#
# ______________________________________________________________________________________________________________________________________________
#
#   Average mathematical exp = 10.607
#   Average standard deviation = 3.477
