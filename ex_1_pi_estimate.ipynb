# %% [markdown]
# # Практическая работа 2.
# # Exercise 1 - pi_estimate

# %% [markdown]
# ## Выполнил студент группы Ньяти Каелиле БВТ2201
# ***

# %% [markdown]
# ### Задание
# Основные понятия статистического эксперемента
#
# ген. сл. чисел от 0 до 1
#
# (Xmax - Xmin) * rand(1) + Xmin (Ymax - Ymin) * rand(1) + Ymin
#
# радиус = (Xmax - Xmin) / 2
#
# R - R0 < del
#
# m - число точек внутри круга n - общее число эксперементов
#
# m/n = Sкруг/Sквадрат = Pi * R0^2 / 4*R0^2 = Pi / 4
#
# 10^3, 10^4, 10^5, 10^6 => Piрасчетное - Pi / Pi * 100 = q
#
# вторая работа
#
# y = x^3 + 1
#
# f(a) = a^3 + 1
#
# f(xp) < yp
#
# S

# %% [markdown]
# ### Выполнение:

# %%
##Exercise 1

import random
import math

r = 5  # Radius of the circle
x0, y0 = 1, 2  # Centre coordinate

# Using input data to find the max and min values of x and y
xmax = x0 + r
xmin = x0 - r
ymax = y0 + r
ymin = y0 - r


def estimate_pi(n):
    m = 0
    for _ in range(n):
        xp = (xmax-xmin)*random.random() + xmin
        yp = (ymax-ymin)*random.random() + ymin

        ''' xp = random.uniform(xmin, xmax)
            yp = random.uniform(ymin, ymax) 
            
            This also produces the same result as the given formulaes above
        '''
        if (xp - x0)**2 + (yp - y0)**2 <= r**2:
            m += 1

    pi_estimate = 4 * (m / n)
    return pi_estimate


def relative_error(pi_estimate):
    return ((abs(pi_estimate - math.pi)) / math.pi) * 100  # Calculate positive relative error


# List of n values
n_values = [10**3, 10**4, 10**5, 10**6, 10**7, 10**8]

# Lists to store results
pi_estimates = []
errors = []

# Loop through the n_values, estimate Pi, and store the results
for n in n_values:
    pi_estimated = estimate_pi(n)
    rel_error = relative_error(pi_estimated)

    pi_estimates.append(pi_estimated)
    errors.append(rel_error)

    print(f"Estimated value of pi for n={n} is {pi_estimated}")
    print(f"Relative error for n={n} is {rel_error}%\n")
# Out:
# Estimated value of pi for n=1000 is 3.16
# Relative error for n=1000 is 0.5859240340778606%
#
# Estimated value of pi for n=10000 is 3.1548
# Relative error for n=10000 is 0.4204028932622794%
#
# Estimated value of pi for n=100000 is 3.1398
# Relative error for n=100000 is 0.057061936013396396%
#
# Estimated value of pi for n=1000000 is 3.141724
# Relative error for n=1000000 is 0.004180886088359035%
#
# Estimated value of pi for n=10000000 is 3.141672
# Relative error for n=10000000 is 0.0025256746801981347%
#
# Estimated value of pi for n=100000000 is 3.14145724
# Relative error for n=100000000 is 0.004310348435484334%

# %%
#Graphical View

import matplotlib.pyplot as plt


# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(n_values, errors, marker='o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Experiments (n)')
plt.ylabel('Relative Error (%)')
plt.title('Relative Error vs. Number of Experiments')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
##Exercise 2

# List of n values
n_values = [10**4, 10**5, 10**6, 10**7, 10**8]

# Function to run experiments and store results
def run_experiment(series):
    # Loop through the n_values, estimate Pi, and print the results
    for n in n_values:
        pi_estimated = estimate_pi(n)
        rel_error = relative_error(pi_estimated)
        series.append(pi_estimated)

        print(f"Estimated value of pi for n={n} is {pi_estimated}")
        print(f"Relative error for n={n} is {rel_error}%\n")


# Initialize lists to store results for each series
Series1 = []
Series2 = []
Series3 = []
Series4 = []
Series5 = []


run_experiment(Series1)
run_experiment(Series2)
run_experiment(Series3)
run_experiment(Series4)
run_experiment(Series5)

# Output the results
print("Series1:", Series1)
print("Series2:", Series2)
print("Series3:", Series3)
print("Series4:", Series4)
print("Series5:", Series5)
# Out:
# Estimated value of pi for n=10000 is 3.1436
# Relative error for n=10000 is 0.06389582073644487%
#
# Estimated value of pi for n=100000 is 3.14364
# Relative error for n=100000 is 0.06516906028117425%
#
# Estimated value of pi for n=1000000 is 3.140896
# Relative error for n=1000000 is 0.022175172487653386%
#
# Estimated value of pi for n=10000000 is 3.1425492
# Relative error for n=10000000 is 0.0304478178962445%
#
# Estimated value of pi for n=100000000 is 3.1417644
# Relative error for n=100000000 is 0.005466858028543189%
#
# Estimated value of pi for n=10000 is 3.1404
# Relative error for n=10000 is 0.03796334284237106%
#
# Estimated value of pi for n=100000 is 3.14236
# Relative error for n=100000 is 0.024425394849650697%
#
# Estimated value of pi for n=1000000 is 3.141916
# Relative error for n=1000000 is 0.010292435903093929%
#
# Estimated value of pi for n=10000000 is 3.1414968
# Relative error for n=10000000 is 0.003051114525732613%
#
# Estimated value of pi for n=100000000 is 3.14144772
# Relative error for n=100000000 is 0.004613379447127295%
#
# Estimated value of pi for n=10000 is 3.158
# Relative error for n=10000 is 0.5222620568410954%
#
# Estimated value of pi for n=100000 is 3.14244
# Relative error for n=100000 is 0.02697187393912357%
#
# Estimated value of pi for n=1000000 is 3.138104
# Relative error for n=1000000 is 0.11104729271017887%
#
# Estimated value of pi for n=10000000 is 3.1409936
# Relative error for n=10000000 is 0.019068467998509205%
#
# Estimated value of pi for n=100000000 is 3.14160808
# Relative error for n=100000000 is 0.0004910378877221025%
#
# Estimated value of pi for n=10000 is 3.1472
# Relative error for n=10000 is 0.17848737976261103%
#
# Estimated value of pi for n=100000 is 3.14464
# Relative error for n=100000 is 0.09700004889954982%
#
# Estimated value of pi for n=1000000 is 3.13912
# Relative error for n=1000000 is 0.07870700827389461%
#
# Estimated value of pi for n=10000000 is 3.1423384
# Relative error for n=10000000 is 0.023737845495488078%
#
# Estimated value of pi for n=100000000 is 3.1416582
# Relative error for n=100000000 is 0.0020864070372766095%
#
# Estimated value of pi for n=10000 is 3.1316
# Relative error for n=10000 is 0.3180760426841043%
#
# Estimated value of pi for n=100000 is 3.14716
# Relative error for n=100000 is 0.17721414021786755%
#
# Estimated value of pi for n=1000000 is 3.143892
# Relative error for n=1000000 is 0.07319046941301026%
#
# Estimated value of pi for n=10000000 is 3.1413224
# Relative error for n=10000000 is 0.00860243894078206%
#
# Estimated value of pi for n=100000000 is 3.1418014
# Relative error for n=100000000 is 0.006644604607418209%
#
# Series1: [3.1436, 3.14364, 3.140896, 3.1425492, 3.1417644]
# Series2: [3.1404, 3.14236, 3.141916, 3.1414968, 3.14144772]
# Series3: [3.158, 3.14244, 3.138104, 3.1409936, 3.14160808]
# Series4: [3.1472, 3.14464, 3.13912, 3.1423384, 3.1416582]
# Series5: [3.1316, 3.14716, 3.143892, 3.1413224, 3.1418014]

# %%
##Exercise 3

Avg_Series1 = sum(Series1)/ len(Series1)
Avg_Series2 = sum(Series2)/ len(Series2)
Avg_Series3 = sum(Series3)/ len(Series3)
Avg_Series4 = sum(Series4)/ len(Series4)
Avg_Series5 = sum(Series5)/ len(Series5)

Avg_of_all_series = (Avg_Series1 + Avg_Series2 + Avg_Series3 + Avg_Series4 + Avg_Series5) / 5

rel_error_Avg_Series1 = relative_error(Avg_Series1)
rel_error_Avg_Series2 = relative_error(Avg_Series2)
rel_error_Avg_Series3 = relative_error(Avg_Series3)
rel_error_Avg_Series4 = relative_error(Avg_Series4)
rel_error_Avg_Series5 = relative_error(Avg_Series5)

rel_err_Avg_of_all_series = relative_error(Avg_of_all_series)

print(f"Estimated value of pi for Avg_Series1 is {Avg_Series1}")
print(f"Estimated value of pi for Avg_Series2 is {Avg_Series2}")
print(f"Estimated value of pi for Avg_Series3 is {Avg_Series3}")
print(f"Estimated value of pi for Avg_Series4 is {Avg_Series4}")
print(f"Estimated value of pi for Avg_Series5 is {Avg_Series5}\n")

print(f"Relative error for Avg_Series1 is {rel_error_Avg_Series1}%")
print(f"Relative error for Avg_Series2 is {rel_error_Avg_Series2}%")
print(f"Relative error for Avg_Series3 is {rel_error_Avg_Series3}%")
print(f"Relative error for Avg_Series4 is {rel_error_Avg_Series4}%")
print(f"Relative error for Avg_Series5 is {rel_error_Avg_Series5}%\n")

print(f"Relative error for Avg_of_all_series is {rel_err_Avg_of_all_series}%")
# Out:
# Estimated value of pi for Avg_Series1 is 3.14248992
# Estimated value of pi for Avg_Series2 is 3.141524104
# Estimated value of pi for Avg_Series3 is 3.144229136
# Estimated value of pi for Avg_Series4 is 3.14299132
# Estimated value of pi for Avg_Series5 is 3.14115516
#
# Relative error for Avg_Series1 is 0.028560876890950684%
# Relative error for Avg_Series2 is 0.0021820012124944403%
# Relative error for Avg_Series3 is 0.08392184159184776%
# Relative error for Avg_Series4 is 0.04452093458420901%
# Relative error for Avg_Series5 is 0.01392585347732372%
#
# Relative error for Avg_of_all_series is 0.028179159675449168%
