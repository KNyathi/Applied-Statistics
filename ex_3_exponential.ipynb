# %% [markdown]
# # Практическая работа 2.
# # Exercise 3 - exponential estimate

# %% [markdown]
# ## Выполнил студент группы Ньяти Каелиле БВТ2201
# ***

# %% [markdown]
# ### Выполнение:

# %%
##Exercise 3

import random
import math

def f(x):
    return math.exp(x**2)

xmin = 0
xmax = 2
ymin = 0
ymax = f(xmax)


def estimate_exponential(n):
    m = 0
    for _ in range(n):
        xp = (xmax-xmin) * random.random() + xmin
        yp = (ymax-ymin) * random.random() + ymin

        if yp <= f(xp):
            m += 1

    sampling_area = (xmax - xmin) * (ymax - ymin)  

    expo_estimate = (m / n) * sampling_area
    return expo_estimate

def relative_error(expo_estimate):
    return ((abs(expo_estimate - 16.45)) / 16.45) * 100  # Calculate positive relative error

# List of n values
n_values = [10**4, 10**5, 10**6, 10**7]

# Lists to store results
exp_estimates = []
errors = []

# Loop through the n_values, estimate Pi, and print the results
for n in n_values:
    expo_estimate = estimate_exponential(n)
    rel_error = relative_error(expo_estimate)
    
    exp_estimates.append(expo_estimate)
    errors.append(rel_error)

    print(f"Estimated value of exponential for n={n} is {expo_estimate}")
    print(f"Relative error for n={n} is {rel_error}%\n")
# Out:
# Estimated value of exponential for n=10000 is 16.597837610075846
# Relative error for n=10000 is 0.8987088758410136%
#
# Estimated value of exponential for n=100000 is 16.43513512297708
# Relative error for n=100000 is 0.09036399406030023%
#
# Estimated value of exponential for n=1000000 is 16.44747430488457
# Relative error for n=1000000 is 0.015353769698665275%
#
# Estimated value of exponential for n=10000000 is 16.45447378771882
# Relative error for n=10000000 is 0.02719627792595144%

# %%
#Graphical View

import matplotlib.pyplot as plt


# Plotting the results
plt.figure(figsize=(10, 6))
plt.plot(n_values, errors, marker='o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Experiments (n)')
plt.ylabel('Relative Error (%)')
plt.title('Relative Error vs. Number of Experiments')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
##Exercise 2

# List of n values
n_values = [10**4, 10**5, 10**6, 10**7, 10**8]

# Function to run experiments and store results
def run_experiment(series):
    # Loop through the n_values, estimate Pi, and print the results
    for n in n_values:
        expo_estimate = estimate_exponential(n)
        rel_error = relative_error(expo_estimate)
        
        series.append(expo_estimate)
        errors.append(rel_error)

        print(f"Estimated value of integral for n={n} is {expo_estimate}")
        print(f"Relative error for n={n} is {rel_error}%\n")


# Initialize lists to store results for each series
Series1 = []
Series2 = []
Series3 = []
Series4 = []
Series5 = []


run_experiment(Series1)
run_experiment(Series2)
run_experiment(Series3)
run_experiment(Series4)
run_experiment(Series5)

# Output the results
print("Series1:", Series1)
print("Series2:", Series2)
print("Series3:", Series3)
print("Series4:", Series4)
print("Series5:", Series5)
# Out:
# Estimated value of integral for n=10000 is 16.27024870987698
# Relative error for n=10000 is 1.092713009866374%
#
# Estimated value of integral for n=100000 is 16.324846859910124
# Relative error for n=100000 is 0.7608093622484795%
#
# Estimated value of integral for n=1000000 is 16.444962789983045
# Relative error for n=1000000 is 0.03062133748908617%
#
# Estimated value of integral for n=10000000 is 16.459606013821933
# Relative error for n=10000000 is 0.05839522080202797%
#
# Estimated value of integral for n=100000000 is 16.451093070268765
# Relative error for n=100000000 is 0.0066448040654463695%
#
# Estimated value of integral for n=10000 is 16.707033910142137
# Relative error for n=10000 is 1.5625161710768238%
#
# Estimated value of integral for n=100000 is 16.49956094001619
# Relative error for n=100000 is 0.30128231012880813%
#
# Estimated value of integral for n=1000000 is 16.442014489881256
# Relative error for n=1000000 is 0.048544134460446066%
#
# Estimated value of integral for n=10000000 is 16.437417325648465
# Relative error for n=10000000 is 0.07649042158987664%
#
# Estimated value of integral for n=100000000 is 16.44737930410351
# Relative error for n=100000000 is 0.01593128204552685%
#
# Estimated value of integral for n=10000 is 15.953579439684747
# Relative error for n=10000 is 3.0177541660501674%
#
# Estimated value of integral for n=100000 is 16.460250271992326
# Relative error for n=100000 is 0.062311683843930286%
#
# Estimated value of integral for n=1000000 is 16.4198476409678
# Relative error for n=1000000 is 0.18329701539331666%
#
# Estimated value of integral for n=10000000 is 16.45424447548868
# Relative error for n=10000000 is 0.025802282605954137%
#
# Estimated value of integral for n=100000000 is 16.450134326754185
# Relative error for n=100000000 is 0.0008165760132861112%
#
# Estimated value of integral for n=10000 is 16.3903646399499
# Relative error for n=10000 is 0.36252498510698045%
#
# Estimated value of integral for n=100000 is 16.335766489916757
# Relative error for n=100000 is 0.6944286327248748%
#
# Estimated value of integral for n=1000000 is 16.472589453899815
# Relative error for n=1000000 is 0.13732190820556522%
#
# Estimated value of integral for n=10000000 is 16.455664027389542
# Relative error for n=10000000 is 0.03443177744402751%
#
# Estimated value of integral for n=100000000 is 16.453897231254466
# Relative error for n=100000000 is 0.023691375407091212%
#
# Estimated value of integral for n=10000 is 15.953579439684747
# Relative error for n=10000 is 3.0177541660501674%
#
# Estimated value of integral for n=100000 is 16.38599678794725
# Relative error for n=100000 is 0.38907727691641375%
#
# Estimated value of integral for n=1000000 is 16.53832562653972
# Relative error for n=1000000 is 0.5369338999375122%
#
# Estimated value of integral for n=10000000 is 16.44591279779362
# Relative error for n=10000000 is 0.024846214020535187%
#
# Estimated value of integral for n=100000000 is 16.45079387240658
# Relative error for n=100000000 is 0.0048259720764884636%
#
# Series1: [16.27024870987698, 16.324846859910124, 16.444962789983045, 16.459606013821933, 16.451093070268765]
# Series2: [16.707033910142137, 16.49956094001619, 16.442014489881256, 16.437417325648465, 16.44737930410351]
# Series3: [15.953579439684747, 16.460250271992326, 16.4198476409678, 16.45424447548868, 16.450134326754185]
# Series4: [16.3903646399499, 16.335766489916757, 16.472589453899815, 16.455664027389542, 16.453897231254466]
# Series5: [15.953579439684747, 16.38599678794725, 16.53832562653972, 16.44591279779362, 16.45079387240658]

# %%
##Exercise 3

Avg_Series1 = sum(Series1)/ len(Series1)
Avg_Series2 = sum(Series2)/ len(Series2)
Avg_Series3 = sum(Series3)/ len(Series3)
Avg_Series4 = sum(Series4)/ len(Series4)
Avg_Series5 = sum(Series5)/ len(Series5)

Avg_of_all_series = (Avg_Series1 + Avg_Series2 + Avg_Series3 + Avg_Series4 + Avg_Series5) / 5

rel_error_Avg_Series1 = relative_error(Avg_Series1)
rel_error_Avg_Series2 = relative_error(Avg_Series2)
rel_error_Avg_Series3 = relative_error(Avg_Series3)
rel_error_Avg_Series4 = relative_error(Avg_Series4)
rel_error_Avg_Series5 = relative_error(Avg_Series5)

rel_err_Avg_of_all_series = relative_error(Avg_of_all_series)

print(f"Estimated value of integral for Avg_Series1 is {Avg_Series1}")
print(f"Estimated value of integral for Avg_Series2 is {Avg_Series2}")
print(f"Estimated value of integral for Avg_Series3 is {Avg_Series3}")
print(f"Estimated value of integral for Avg_Series4 is {Avg_Series4}")
print(f"Estimated value of integral for Avg_Series5 is {Avg_Series5}\n")

print(f"Relative error for Avg_Series1 is {rel_error_Avg_Series1}%")
print(f"Relative error for Avg_Series2 is {rel_error_Avg_Series2}%")
print(f"Relative error for Avg_Series3 is {rel_error_Avg_Series3}%")
print(f"Relative error for Avg_Series4 is {rel_error_Avg_Series4}%")
print(f"Relative error for Avg_Series5 is {rel_error_Avg_Series5}%\n")

print(f"Relative error for Avg_of_all_series is {rel_err_Avg_of_all_series}%")
# Out:
# Estimated value of integral for Avg_Series1 is 16.39015148877217
# Estimated value of integral for Avg_Series2 is 16.50668119395831
# Estimated value of integral for Avg_Series3 is 16.347611230977545
# Estimated value of integral for Avg_Series4 is 16.421656368482097
# Estimated value of integral for Avg_Series5 is 16.354921704874382
#
# Relative error for Avg_Series1 is 0.36382073694729733%
# Relative error for Avg_Series2 is 0.34456652862195647%
# Relative error for Avg_Series3 is 0.6224241277960735%
# Relative error for Avg_Series4 is 0.17230171135502995%
# Relative error for Avg_Series5 is 0.5779835569946339%
#
# Relative error for Avg_of_all_series is 0.27839272089421563%
